# %% [markdown]
# <div class="alert alert-info">
# <b>Евгений, добрый день!
#     Спасибо за ревью и твои комментарии. Постарался исправить в соответствии с твоими замечаниями. Надеюсь, сейчас мой проект выглядит лучше. Хорошего дня! :)
#     </b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Александр, привет!  Сейчас все проверим ;) Хорошего дня и тебе!

# %% [markdown]
# <div class="alert alert-info">
# <b>    В рамках выполнения сборного проекта предлагается провести исследование по заказу Министерства Культуры РФ. Необходимо проанализировать данные о российском кинопрокате, особенно обратить внимание на фильмы, получившие государственную поддержку. Данные для анализа взяты с сервиса Яндекса - Кинопоиска.
#     </b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Введение есть, отлично

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_movies = pd.read_csv('/datasets/mkrf_movies.csv')
data_shows = pd.read_csv('/datasets/mkrf_shows.csv')

display(data_movies)
display(data_shows)
# Out:
#                                              title   puNumber  \
# 0                                 Открытый простор  221048915
# 1                             Особо важное задание  111013716
# 2                                     Особо опасен  221038416
# 3                                     Особо опасен  221026916
# 4                                     Особо опасен  221030815
# ...                                            ...        ...
# 7481     Сад художника: Американский импрессионизм  126008019
# 7482                               Звериная ярость  121037819
# 7483     Щенячий патруль: Скорей спешим на помощь!  124010819
# 7484      Машины песенки. Серия "Испанские мотивы"  124010619
# 7485  Машины песенки. Серия "Когда цветут кактусы"  124010719
#
#                show_start_date             type  \
# 0     2015-11-27T12:00:00.000Z   Художественный
# 1     2016-09-13T12:00:00.000Z   Художественный
# 2     2016-10-10T12:00:00.000Z   Художественный
# ...

# %%
data_movies = data_movies[data_movies['puNumber'] != 'нет']
data_movies['puNumber'] = data_movies['puNumber'].astype('int64')

# %%
data = pd.merge(data_movies, data_shows, how='left')
display(data)
# Out:
#                                              title   puNumber  \
# 0                                 Открытый простор  221048915
# 1                             Особо важное задание  111013716
# 2                                     Особо опасен  221038416
# 3                                     Особо опасен  221026916
# 4                                     Особо опасен  221030815
# ...                                            ...        ...
# 7480     Сад художника: Американский импрессионизм  126008019
# 7481                               Звериная ярость  121037819
# 7482     Щенячий патруль: Скорей спешим на помощь!  124010819
# 7483      Машины песенки. Серия "Испанские мотивы"  124010619
# 7484  Машины песенки. Серия "Когда цветут кактусы"  124010719
#
#                show_start_date             type  \
# 0     2015-11-27T12:00:00.000Z   Художественный
# 1     2016-09-13T12:00:00.000Z   Художественный
# 2     2016-10-10T12:00:00.000Z   Художественный
# ...

# %% [markdown]
# <div class="alert alert-info">
#     <b>На первом шаге выполнил слияние датафремов так, чтобы все строки из первого датафрейма попали в итоговый общий. Для этого потребовалось привести тип данных общего столбца к одному виду в обоих датафреймах.</b>
# </div>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   puNumber               7485 non-null   int64
#  2   show_start_date        7485 non-null   object
#  3   type                   7485 non-null   object
#  4   film_studio            7467 non-null   object
#  5   production_country     7483 non-null   object
#  6   director               7476 non-null   object
#  7   producer               6917 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %%
data['show_start_date'] = pd.to_datetime(data['show_start_date'], format='%Y.%m.%dT%H:%M:%S')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   puNumber               7485 non-null   int64
#  2   show_start_date        7485 non-null   datetime64[ns, UTC]
#  3   type                   7485 non-null   object
#  4   film_studio            7467 non-null   object
#  5   production_country     7483 non-null   object
#  6   director               7476 non-null   object
#  7   producer               6917 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хорошо! Но хотелось бы, конечно, чтобы работу со столбцов рейтинг ты совершил здесь, а не в разделе ниже, а то сначал апоставил тебе желтый коммент ;)

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %%
#Заполнение пропусков категориальных переменных
data['production_country'] = data['production_country'].fillna(0).replace(0, 'unknown')
data['film_studio'] = data['film_studio'].fillna(0).replace(0, 'unknown')
data['director'] = data['director'].fillna(0).replace(0, 'unknown')
data['producer'] = data['producer'].fillna(0).replace(0, 'unknown')
data['genres'] = data['genres'].fillna(0).replace(0, 'unknown')
data = data.loc[~((pd.to_numeric(data['ratings'], errors='coerce').isna()) & (data['ratings'].notna()))]
data['ratings'] = data['ratings'].astype('float64')

# %%
#Check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7456 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7456 non-null   object
#  1   puNumber               7456 non-null   int64
#  2   show_start_date        7456 non-null   datetime64[ns, UTC]
#  3   type                   7456 non-null   object
#  4   film_studio            7456 non-null   object
#  5   production_country     7456 non-null   object
#  6   director               7456 non-null   object
#  7   producer               7456 non-null   object
#  8   age_restriction        7456 non-null   object
#  9   refundable_support     330 non-null    float64
#  10  nonrefundable_support  330 non-null    float64
#  11  budget                 330 non-null    float64
#  12  financing_source       330 non-null    object
#  13  ratings                6490 non-null   float64
# ...

# %% [markdown]
# <div class="alert alert-info">
# <b>Вставил заглушки, поменял тип данных в столбце ratings</b>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Хорошо, но опять не хваатет вывода. А ведь это так просто! "Вставил заглушки" и все

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, хорошо

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %%
data[data['puNumber'].duplicated(keep=False)]
# Out:
#                                                   title   puNumber  \
# 4637                   Как жениться и остаться холостым  221154310
# 4638  Иоанна - женщина на папском престоле /По роман...  221154310
# 5066                                    Анализируй это!  221054410
# 5067                                     Анализируй то!  221054410
#
#                show_start_date            type  \
# 4637 2010-12-17 12:00:00+00:00  Художественный
# 4638 2010-12-17 12:00:00+00:00  Художественный
# 5066 2010-05-25 12:00:00+00:00  Художественный
# 5067 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4637  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4638   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
# 5066          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 5067  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#                                 production_country        director  \
# ...

# %% [markdown]
# В столбце puNumber есть 2 дубликата. Их связывает только дата и время старта показа. Возможно, что дубликат номера проката всего-лишь случайность или опечатка.

# %%
data[data['title'].duplicated(keep=False)]
# Out:
#                                                   title   puNumber  \
# 2                                          Особо опасен  221038416
# 3                                          Особо опасен  221026916
# 4                                          Особо опасен  221030815
# 12    Малышка на миллион /По мотивам рассказов Ф.Х.Т...  221011415
# 26                                      Оружейный барон  221012515
# ...                                                 ...        ...
# 7368                                          Невиновен  111019319
# 7415                             Отель "Гранд Будапешт"  121035119
# 7437                                              Зверь  121035919
# 7449                                      В тихом омуте  121036919
# 7473                                          Вторжение  111022519
#
#                show_start_date             type  \
# 2    2016-10-10 12:00:00+00:00   Художественный
# 3    2016-06-10 12:00:00+00:00   Художественный
# ...

# %% [markdown]
# Дубликаты в столбце title могут быть связаны с различными типами лицензий для проката. Например, для показа в кино, для телевидения, повторный прокат старого фильма. Данные дубликаты было решено оставить.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> А здесь все верно, молодец)

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['type'] = data['type'].str.strip()
#Check
print(data['type'].unique())
# Out:
# ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
#  'Научно-популярный' 'Музыкально-развлекательный']

# %%
data['genres'].nunique()
# Out:
# 740

# %%
data['film_studio'] = data['film_studio'].str.strip()
display(data['film_studio'].nunique())
#display(data['film_studio'].head(30))
# Out:
# 5442

# %%
#data['production_country'].unique()
#data['production_country'].nunique()
data['production_country'] = data['production_country'].str.replace('-', ',')
data['production_country'] = data['production_country'].str.replace(' - ', ',')
data['production_country'] = data['production_country'].str.replace(',', ', ')
data['production_country'] = data['production_country'].str.replace(' ,', ',')
data['production_country'].unique()
data['production_country'].nunique()
# Out:
# 904

# %% [markdown]
# В столбце Production_country по-разному записаны данные, где несколько стран участниц. Наименования стран были приведены к единому общего виду, вследвие чего количество уникальных значений сократилось с 951 до 908.

# %%
data['director'].value_counts()
data['director'].nunique()
# Out:
# 4794

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Все верно - проблемы убрали, огромное количество неявных дублей есть не только в столбце со странами, но и в столбце с жанром, например, но здесь мы бессильны

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %%
data_money = data[data['budget'].isnull() == False]
display(data_money.head(30))
# Out:
#                                                   title   puNumber  \
# 1281                                      Пока еще жива  111005313
# 1448                                Бесславные придурки  111003314
# 1498                                          Невидимки  111004213
# 1524                                              БЕРЦЫ  111004314
# 1792                                           Братья Ч  111004414
# 1853          Тайна Сухаревой башни. Чародей равновесия  114000115
# 1869                             А зори здесь тихие..._  111002915
# 1870                                        Две женщины  111013714
# 1902                                          Призрак_.  111001815
# 1911                                           Ведьма .  111002215
# 1986                                      Елки Лохматые  111023114
# 1990                                            Смайлик  111008614
# 1996               Овечка Долли была злая и рано умерла  111015214
# ...

# %% [markdown]
# <div class="alert alert-info">
# <b>Бюджет фильма больше, чем сумма средств государственной поддержки. Это говорит лишь о том, что помимо государства, у фильма были и другие спонсоры</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Не понял, а в чем здесь проблема? Получили поддержку, да. Я бы здесь, конечно, говорил скорее о том, что сумма поддержек не должна быть больше, чем бюджет.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Так, я тебя запутал. Сумма поддержке не должна быть конечно же больше, чем бюджет. Вот что здесь стоит проверить

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
data['start_date_year'] = data['show_start_date'].dt.year
data['start_date_year'].unique()
# Out:
# array([2015, 2016, 2013, 2014, 2012, 2017, 2010, 2011, 2018, 2019])

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
def first_value(series):
    series = series.split(',')
    return series[0]
    
data['general_genre'] = data['genres'].apply(first_value)
data['fullname_director'] = data['director'].apply(first_value)
display(data.head())
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          Особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          Особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          Особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
# ...

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
data['budget_share'] = (data['refundable_support'] + data['nonrefundable_support']) / data['budget'] * 100
data_money = data[data['budget_share'].isnull() == False]
display(data_money.head())
# Out:
#                     title   puNumber           show_start_date  \
# 1281        Пока еще жива  111005313 2013-10-11 12:00:00+00:00
# 1448  Бесславные придурки  111003314 2014-03-28 12:00:00+00:00
# 1498            Невидимки  111004213 2013-09-10 12:00:00+00:00
# 1524                БЕРЦЫ  111004314 2014-05-05 12:00:00+00:00
# 1792             Братья Ч  111004414 2014-04-23 12:00:00+00:00
#
#                 type                                        film_studio  \
# 1281  Художественный  АНО содействия развитию кинематографии "Ангел-...
# 1448  Художественный                         ООО "Компания "АТК-Студио"
# 1498  Художественный                        ООО "Компания "РЕАЛ-ДАКОТА"
# 1524  Художественный                             ООО "Студия "Пассажир"
# 1792  Художественный                             ООО "Студия "Пассажир"
#
#      production_country                              director  \
# 1281             Россия                            А.Атанесян
# ...

# %% [markdown]
# В столбце budget_share посчитана доля госудратсвенного финансирования от общего бюджета в процентах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, хорошо)

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %%
box_office_films =(data.query('box_office.notna()')['start_date_year'].value_counts().sort_index() /
                       data['start_date_year'].value_counts()                        
                       *100)
display(box_office_films)
# Out:
# 2010    10.670732
# 2011    17.552335
# 2012    21.489002
# 2013    29.252782
# 2014    34.534161
# 2015    65.997131
# 2016    64.329643
# 2017    70.775348
# 2018    53.378378
# 2019    56.972973
# Name: start_date_year, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Так, хорошо

# %% [markdown]
# Информации о прокате в кинотетрах до 2015 года меньше полопвины от всех фильмов.

# %%
(box_office_films
 .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
);

# %% [markdown]
# По графику видно, что минимальной доля фильмов с указанной информацией о прокате была в 2010 году, а максимальной - в 2017. Причем начиная с 2015 года информации в разы больше, чем в 2010 - 2014 годах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> И здесь тоже хорошо, только я бы убрал сортировку, чтобы было лучше видно тренд по годам

# %% [markdown]
# <div class="alert alert-info">
# <b>Убрал сортировку</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  Не очень понял, почему данные до 2015 нужно отрезать. Понял, что их меньше, это правда, но не стоит их отрезать. Давай поправим все разделы ниже, хорошо?

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
box_office_total = data_money.pivot_table(index='start_date_year', values='box_office')
print(box_office_total)

(box_office_total
 .sort_values(by='box_office', ascending='True')
 .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
);
# Out:
#                    box_office
# start_date_year
# 2013             1.016119e+07
# 2014             6.714588e+07
# 2015             6.252742e+07
# 2016             8.697762e+07
# 2017             2.907977e+08
# 2018             1.830319e+08
# 2019             1.400342e+08

# %% [markdown]
# В расчёт были взяты данные с 2015 года. Как видно по графику, самые большие кассовые сборы были в 2017 году, а наименьшие - в 2013. ДЛя получения более достоверной информации посчитаем медиану и среднее по годам.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Хорошо

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %%
pivot_table_by_year = data.query('box_office.notna()').groupby('start_date_year').agg({'box_office': ['mean', 'median']}).reset_index()
pivot_table_by_year.columns = ['year', 'mean', 'median']

print(pivot_table_by_year)

(pivot_table_by_year
 .pivot_table(index='year', values='mean')
 .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = True, fontsize = 16)
);

(pivot_table_by_year
 .pivot_table(index='year', values='median')
 .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16)
);
# Out:
#    year          mean        median
# 0  2010  2.313004e+04  1.700000e+03
# 1  2011  1.293832e+05  3.000000e+03
# 2  2012  5.475341e+04  5.760000e+03
# 3  2013  1.619549e+05  3.522500e+03
# 4  2014  2.678039e+07  1.888500e+04
# 5  2015  8.470884e+07  5.003450e+06
# 6  2016  9.151611e+07  4.000811e+06
# 7  2017  1.364148e+08  1.017783e+07
# 8  2018  1.047823e+08  8.911534e+06
# 9  2019  9.188060e+07  4.732610e+06

# %% [markdown]
# 2017 снова самый прибильный и по медианным, и по средним значениям. Наиболее точную картину показывает второй график, то есть медианные значения кассовых сборов по годам. До 2015 года сборов в разы меньше. Возможно, до 2015 года учёт вёлся некорректно, либо использовались другие единицы измерения.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>  До этого момента нужно поправить получается

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Ага, хорошо, молодец!

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %%
data_age = (data_money
            .pivot_table(index=['start_date_year', 'age_restriction'], values='box_office', aggfunc=['mean', 'median'])
           )
data_age.columns = ['mean', 'median']

data_age_in_2013 = data_age.query('start_date_year == 2013')
data_age_in_2014 = data_age.query('start_date_year == 2014')
data_age_in_2015 = data_age.query('start_date_year == 2015')
data_age_in_2016 = data_age.query('start_date_year == 2016')
data_age_in_2017 = data_age.query('start_date_year == 2017')
data_age_in_2018 = data_age.query('start_date_year == 2018')
data_age_in_2019 = data_age.query('start_date_year == 2019')

display(data_age_in_2013.sort_values(by='median', ascending=False))
display(data_age_in_2014.sort_values(by='median', ascending=False))
display(data_age_in_2015.sort_values(by='median', ascending=False))
display(data_age_in_2016.sort_values(by='median', ascending=False))
display(data_age_in_2017.sort_values(by='median', ascending=False))
display(data_age_in_2018.sort_values(by='median', ascending=False))
display(data_age_in_2019.sort_values(by='median', ascending=False))
# Out:
#                                                        mean      median
# start_date_year age_restriction
# 2013            «12+» - для детей старше 12 лет  19957031.5  19957031.5
#                 «16+» - для детей старше 16 лет    365353.6    365353.6
#                                                                 mean  \
# start_date_year age_restriction
# 2014            «0+» - для любой зрительской аудитории  1.728673e+08
#                 «6+» - для детей старше 6 лет           1.212256e+08
#                 «18+» - запрещено для детей             4.482190e+07
#                 «12+» - для детей старше 12 лет         8.958333e+07
#                 «16+» - для детей старше 16 лет         2.150239e+06
#
#                                                               median
# start_date_year age_restriction
# 2014            «0+» - для любой зрительской аудитории  1.728673e+08
#                 «6+» - для детей старше 6 лет           1.212256e+08
# ...

# %% [markdown]
# Каждый год в период с 2015 по 2019, исключая 2018, самой доходной возрастной категорией фильмов была категория 6+. Также очень популярна категория 12+. Можно это объяснить тем, что на подобные фильмы часто ходят семьёй с детьми. На 18+ не пойдёшь с ребёнком, а 0+ совсем детские. Поэтому категории 6+ и 12+ являются самими доходными.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> А вот здесь все хорошо

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %%
data_money = data_money[data_money['budget'] > 0]
data_money['support'] = data_money['refundable_support'] + data_money['nonrefundable_support']
data_money['support'].describe()
# Out:
# count    3.130000e+02
# mean     6.004479e+07
# std      7.319807e+07
# min      3.000000e+06
# 25%      2.534500e+07
# 50%      3.500000e+07
# 75%      6.000000e+07
# max      5.000000e+08
# Name: support, dtype: float64

# %% [markdown]
# Среднее значение суммы государственной поддержки = 60 млн.руб.; медианное - 35 млн.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Так, хорошо, что еще посмотрим

# %%
data_money['profit'] = data_money['box_office'] - data_money['budget']
print('Количество убыточных фильмов:', len(data_money[data_money['profit'] <0]))
print('Количество прибыльных фильмов:', len(data_money[data_money['profit'] >0]))
# Out:
# Количество убыточных фильмов: 233
# Количество прибыльных фильмов: 66

# %%
data_money['ratings'].describe()
# Out:
# count    298.000000
# mean       6.015436
# std        1.133406
# min        1.000000
# 25%        5.400000
# 50%        6.200000
# 75%        6.700000
# max        8.500000
# Name: ratings, dtype: float64

# %%
data_without_money = data[data['budget_share'].isnull() == True]
data_without_money['ratings'].describe()
# Out:
# count    6176.000000
# mean        6.503578
# std         1.095038
# min         1.100000
# 25%         5.900000
# 50%         6.600000
# 75%         7.300000
# max         9.200000
# Name: ratings, dtype: float64

# %% [markdown]
# В среднем рейтинг фильмов выше у фильмов без государственной поддержки. Также среди фильмов с государственной поддержкой количество убыточных фильмов больше, чем прибыльных почти в 4 раза!

# %%
(data
 .pivot_table(index='start_date_year', values='fullname_director', aggfunc='count')
 .plot(kind='barh', figsize=(19, 6),  xlabel='Год выпуска', legend=False)
);

# %% [markdown]
# <div class="alert alert-info">
# <b>Самое большое количество фильмов было выпущено в 2010 году. Наименьшее - в 2017, причем разница почти в 2 раза.</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Интересно, в связи с чем 2017 год получился таким слабым

# %%
(data
 .pivot_table(index='fullname_director', values='title', aggfunc='count')
 .sort_values(by='title' ,ascending=False)
)
# Out:
#                               title
# fullname_director
# О.Семёнова                       47
# Стивен Содерберг                 17
# Д.Червяцов                       16
# Ридли Скотт                      16
# Тиль Швайгер                     14
# ...                             ...
# Е.Севастьянов                     1
# Е.Семенов                         1
# Е.Сергеев                         1
# Е.Сокуров                         1
# хореография Фредерика Эштона      1
#
# [4595 rows x 1 columns]

# %%
(data_money
 .pivot_table(index='fullname_director', values='support')
 .sort_values(by='support', ascending=False)
)
# Out:
#                                                 support
# fullname_director
#  Ф.Бондарчук                                500000000.0
# А.Кравчук                                   500000000.0
# А.Мизгирев                                  450000000.0
# Н.Лебедев                                   442104482.0
# А.Мегердичев                                400000000.0
# ...                                                 ...
# А.Романец                                    11520000.0
# А.Сурикова                                   10000000.0
# Е.Жигаева                                     8000000.0
# Е.Константинова (псевдоним Алена Званцева)    5000000.0
# А.Попова                                      3000000.0
#
# [256 rows x 1 columns]

# %% [markdown]
# <div class="alert alert-info">
# <b>Самой большой гос. поддержкой пользуются Ф.Бондарчук и А.Кравчук - они оба получили по 500 млн. от государства.
#     Больше всего фильмов срежессировала О. Семёнова - 47 проектов. Она лидирует по этому показателю с большим отрывом.</b>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Да, верно

# %%
(data
 .pivot_table(index='general_genre', values='ratings', aggfunc='median')
 .sort_values(by='ratings', ascending=False)
)
# Out:
#                  ratings
# general_genre
# вестерн             7.90
# концерт             7.90
# фильм-нуар          7.60
# аниме               7.60
# документальный      7.30
# детский             7.20
# музыка              7.20
# мюзикл              7.10
# спорт               7.00
# биография           6.90
# драма               6.80
# фантастика          6.70
# мелодрама           6.70
# боевик              6.70
# детектив            6.65
# военный             6.65
# фэнтези             6.60
# триллер             6.60
# криминал            6.60
# мультфильм          6.50
# приключения         6.50
# история             6.40
# короткометражка     6.10
# комедия             6.10
# семейный            5.80
# ужасы               5.70
# реальное ТВ         5.60
# unknown             5.20
# для взрослых        4.10

# %% [markdown]
# <div class="alert alert-info">
# <b>Самые высокие оценки у вестернов и концертов, а вот фильмы категории 'Для взрослых' получают в среднем самые низкие оценки.</b>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Интересные показатели посмотрели, но маловато. ДАвай что-нибудь еще подумаем? Может быть динамику по годам чего-нибудь, чтобы устанвоить тренд? Или самого спонструемого режиссера?

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> ПОсмотрели и другие параметры, хорошо

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# В ходе исследования в рамках сборного проекта было выявлено:
#
# 1. Самый прибыльный год по медианным и средним значениям кассовых сборов - 2017
# 2. Самые прибыльные категории фильмов - 6+ и 12+, предположительно из-за возможности сходить в кино с семьёй и ребёнком.
# 3. Медианное значение поддержки фильмов государством составляет 35 млн., причем убыточных фильмов практически в 4 раза больше чем прибыльных.
# 4. Рейтинг у фильмов без поддержки в среднем выше, чем у фильмов с государственным финансированием.
# 5. Самыми финансируемыми режиссёрами являются Ф.Бондарчук и А.Кравчук, а самым 'продуктивным' режиссёром является О.Семёнова - она была гланвым режиссёром в 47 фильмах!
# 6. Лучше всего пользователи оценивают вестерны и концерты. Медианное значение рейтинга этих жанров составляет 7.90

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Тоже маловато, я бы добавил деталей

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Деталей добавили)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
#  Александр, спасибо за  проект! Ты приложил много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты большой молодец!
#
# **Отмечу положительные моменты**:
#
#     1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть
#
#     2. Отличные визуализации
#
#     2. На разных шагах проекта ты предлагал очень интересные решения и методы для их реализации. Хорошая работа!
#
#
# **На что стоит обратить внимание**:
#
#     1. Ошибка в проверке количественных данных
#
#     2. Отрезаны данные до 2015 года, чего делать не стоит
#
# **Удачи и жду твой проект на повторное ревью!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера v2**:
#  Александр, ошибки исправлены, проект зачтен, поздравляю тебя! Успешной учебы и еще увидимся в Практикуме!
